# %% [markdown]
# # Data Exploration for Heterogeneous Graphs
# Run this notebook to verify data logic individually. Note: Install the kernel locally if unassigned.

# %%
import sys
import os
sys.path.append(os.path.dirname(os.getcwd()))

from data.dataset import get_dataset

train_data, val_data, test_data, dataset = get_dataset()
print("Number of Node Types:", dataset.num_node_types)
print("Node Data Distribution Layout: ", train_data)
